# %%
# run dependencies
# !pip install xgboost
# !pip install shap

import pandas as pd
import numpy as np
import seaborn as sn
from sqlalchemy import create_engine

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# import xgboost
# import shap

import matplotlib.pyplot as plt

# %%
# CSV FILES
player_appearances_csv = "Data/player_appearances.csv"
players_csv = "Data/players.csv"
matches_csv = "Data/matches.csv"
data2021_csv = "Data/Players_EAFIFA/2021.csv"

# %%
# READ CSV FILES
playerApps_df = pd.read_csv(player_appearances_csv)
player_df = pd.read_csv(players_csv)
data_df = pd.read_csv(data2021_csv)
matches_df = pd.read_csv(matches_csv)

# CLEAN UP 
playerApps_df["Name"] = playerApps_df["given_name"] + " " + playerApps_df["family_name"]

dict = {'Overal': 'Overall',
        'Natinality': 'Country'}
data_df.rename(columns=dict,inplace = True)


pd.set_option('display.max_columns', None)

# %%
# CREATE GROUPED DATAFRAME SHOWING LIFETIME NUMBER OF WORLD CUP MATCHES 
playersApps_df_grp = playerApps_df[["match_id", "player_id", "Name"]].\
                            groupby(["player_id", "Name"]).nunique("match_id")
# playersApps_df_grp

# %%
# IDENTIFYING 2022 WORLD CUP QUALIFYING TEAMS
teams_2022 = ['Qatar', 'Netherlands', 'Senegal', 'Ecuador', 
            'England', 'United States', 'Wales', 'Iran', 
            'Argentina', 'Poland', 'Mexico', 'Saudi Arabia', 
            'France', 'Denmark', 'Tunisia', 'Australia', 
            'Germany', 'Spain', 'Japan', 'Costa Rica', 
            'Belgium', 'Croatia', 'Canada', 'Morocco', 
            'Brazil', 'Switzerland', 'Serbia', 'Cameroon', 
            'Portugal', 'Uruguay', 'Ghana', 'Korea Republic']

# %%
# MERGING DATAFRAMES

# MERGE PLAYER APPEARNACES WITH PLAYER DATA TO GET ADDITIONAL DETAIL PER PLAYER
player_info_df = pd.merge(playerApps_df, player_df, on = "player_id", how= "inner")

# MERGE LIFETIME NUMBER OF WORLD CUP MATCHES ONTO PLAYER RECORDS FROM FIFA 2021 PLAYER SET
df_wc = pd.merge(data_df,playersApps_df_grp, on="Name", how="left")
df_wc = df_wc.rename(columns={"match_id":"Lifetime_WC_Matches"})

# ---------- ADDING COLUMNS TO SERVE AS TARGETS: ----------
# LIFETIME WORLD CUP APPEARANCES (TOTAL NUMBERS)
df_wc.loc[df_wc["Lifetime_WC_Matches"].notnull(), "Lifetime_WC_Matches_Bin"]=1
# ----------
# BINARY: WHERE LIFETIME MATCHES IS MORE THAN 3 
    # (INDICATES ADVANCING THROUGH THE GROUP STAGE IF PLAYED IN ONE YEAR'S WORLD CUP \
    # OR MULTIPLE, SINGLE APPEARNACES AS QUALIFYING TEAM)
df_wc.loc[df_wc["Lifetime_WC_Matches"]>3, "Lifetime_WC_Matches_Bin4"]=1

# ----------
# BINARY: WHERE LIFETIME MATCHES IS MORE THAN 4 
df_wc.loc[df_wc["Lifetime_WC_Matches"]>4, "Lifetime_WC_Matches_Bin5"]=1

# ----------
# BINARY: WHERE LIFETIME MATCHES IS AT LEAST 9 (APPX MIDPOINT OF LIFETIME WC MATCHES VALUE COUNTS)
df_wc.loc[df_wc["Lifetime_WC_Matches"]>=9, "Lifetime_WC_Matches_Bin10"]=1

# df_wc.info()

# %%
# VIEW DATAFRAMES

# playerApps_df.head()
# player_info_df.head()
# matches_df.head()
# data_df.head()
# df_wc.head()
player_df.head()
# Out:
#    key_id player_id family_name given_name  birth_date  goal_keeper  defender  \
# 0       1   P-05074     A'Court       Alan  1934-09-30            0         0
# 1       2   P-00942   Abadzhiev     Stefan  1934-07-03            0         0
# 2       3   P-03051       Abalo  Jean-Paul  1975-06-26            0         1
# 3       4   P-03371      Abanda    Patrice  1978-08-03            0         1
# 4       5   P-04977       Abate    Ignazio  1986-11-12            0         1
#
#    midfielder  forward  count_tournaments list_tournaments  \
# 0           0        1                  1             1958
# 1           0        1                  1             1966
# 2           0        0                  1             2006
# 3           0        0                  1             1998
# 4           0        0                  1             2014
#
#                             player_wikipedia_link
# 0    https://en.wikipedia.org/wiki/Alan_A%27Court
# 1  https://en.wikipedia.org/wiki/Stefan_Abadzhiev
# 2   https://en.wikipedia.org/wiki/Jean-Paul_Abalo
# 3    https://en.wikipedia.org/wiki/Patrice_Abanda
# 4     https://en.wikipedia.org/wiki/Ignazio_Abate

# %%
# # iterating the columns
# for col in player_info_df.columns:
#     print(col)

print("PLAYER_INFO_DF COLUMNS")
print(player_info_df.columns)
print("-"*50)
print("MATCHES_DF COLUMNS")
print(matches_df.columns)
print("-"*50)
print("PLAYERAPPS_DF")
print(playerApps_df.columns)
# Out:
# PLAYER_INFO_DF COLUMNS
# Index(['key_id_x', 'tournament_id', 'tournament_name', 'match_id',
#        'match_name', 'match_date', 'stage_name', 'group_name', 'team_id',
#        'team_name', 'team_code', 'home_team', 'away_team', 'player_id',
#        'family_name_x', 'given_name_x', 'shirt_number', 'position_name',
#        'position_code', 'starter', 'substitute', 'captain', 'Name', 'key_id_y',
#        'family_name_y', 'given_name_y', 'birth_date', 'goal_keeper',
#        'defender', 'midfielder', 'forward', 'count_tournaments',
#        'list_tournaments', 'player_wikipedia_link'],
#       dtype='object')
# --------------------------------------------------
# MATCHES_DF COLUMNS
# Index(['key_id', 'tournament_id', 'tournament_name', 'match_id', 'match_name',
#        'stage_name', 'group_name', 'group_stage', 'knockout_stage', 'replayed',
#        'replay', 'match_date', 'match_time', 'stadium_id', 'stadium_name',
#        'city_name', 'country_name', 'home_team_id', 'home_team_name',
#        'home_team_code', 'away_team_id', 'away_team_name', 'away_team_code',
#        'score', 'home_team_score', 'away_team_score', 'home_team_score_margin',
#        'away_team_score_margin', 'extra_time', 'penalty_shootout',
#        'score_penalties', 'home_team_score_penalties',
#        'away_team_score_penalties', 'result', 'home_team_win', 'away_team_win',
#        'draw'],
#       dtype='object')
# --------------------------------------------------
# PLAYERAPPS_DF
# Index(['key_id', 'tournament_id', 'tournament_name', 'match_id', 'match_name',
#        'match_date', 'stage_name', 'group_name', 'team_id', 'team_name',
#        'team_code', 'home_team', 'away_team', 'player_id', 'family_name',
#        'given_name', 'shirt_number', 'position_name', 'position_code',
#        'starter', 'substitute', 'captain', 'Name'],
#       dtype='object')

# %%
# df_wc.info()

# THE NUMBER OF PLAYERS PER COUNTRY BY LIFETIME WORLD CUP APPEARANCE BIN
player_ct_country_wcMatches_beta = df_wc[["Country", 
                                          "ID", 
                                          "Lifetime_WC_Matches_Bin", 
                                          "Lifetime_WC_Matches_Bin4", 
                                          "Lifetime_WC_Matches_Bin5", 
                                          "Lifetime_WC_Matches_Bin10"]].groupby("Country").count()

fifa2021_playerct = df_wc[["Country", "ID"]].groupby("Country").count().sort_values("ID", ascending = False)
# fifa2021_playerct

player_ct_country_wcMatches.sort_values("Lifetime_WC_Matches_Bin10", ascending = False).head(50)

player_ct_country_wcMatches = player_ct_country_wcMatches.rename(columns = {"ID_x": "Total FIFA 2021 Players", 
                                              "Lifetime_WC_Matches_Bin": "Players w/ Any WC Apperances",
                                              "Lifetime_WC_Matches_Bin4": "Players w/ 4+ WC Apperances",
                                              "Lifetime_WC_Matches_Bin5": "Players w/ 5+ WC Apperances",
                                              "Lifetime_WC_Matches_Bin19": "Players w/ 9+ WC Apperances"})

player_ct_country_wcMatches
# player_ct_country_wcMatchesc.loc[player_ct_country_wcMatches["Lifetime_WC_Matches"]>3, "Lifetime_WC_Matches_Bin4"]=1
# Out:
#              Total FIFA 2021 Players  Lifetime_WC_Matches  \
# Country
# Afghanistan                        2                    0
# Albania                           50                    0
# Algeria                           54                    9
# Andorra                            1                    0
# Angola                            21                    0
# ...                              ...                  ...
# Uzbekistan                         8                    0
# Venezuela                        201                    1
# Wales                            123                    0
# Zambia                             9                    0
# Zimbabwe                          14                    0
#
#              Players w/ Any WC Apperances  Players w/ 4+ WC Apperances  \
# Country
# Afghanistan                             0                            0
# Albania                                 0                            0
# Algeria                                 9                            3
# Andorra                                 0                            0
# Angola                                  0                            0
# ...                                   ...                          ...
# Uzbekistan                              0                            0
# Venezuela                               1                            0
# Wales                                   0                            0
# Zambia                                  0                            0
# Zimbabwe                                0                            0
#
#              Players w/ 5+ WC Apperances  Lifetime_WC_Matches_Bin10
# Country
# Afghanistan                            0                          0
# Albania                                0                          0
# Algeria                                1                          0
# Andorra                                0                          0
# Angola                                 0                          0
# ...                                  ...                        ...
# Uzbekistan                             0                          0
# Venezuela                              0                          0
# Wales                                  0                          0
# Zambia                                 0                          0
# Zimbabwe                               0                          0
#
# [163 rows x 6 columns]

# %% [markdown]
# * Create a model to predict which features indicate a winning team.

# %%
# REMOVING IRRELEVANT COLUMNS
df_model = df_wc.select_dtypes(exclude=['object'])
df_model = df_model.drop(columns=["Value", "Wage", "Nation_KitNumber", "ID", "Club_KitNumber"])

# FILLNA ON TARGET COLUMNS
df_model["Lifetime_WC_Matches"] = df_model["Lifetime_WC_Matches"].fillna(0)
df_model["Lifetime_WC_Matches"] = df_model["Lifetime_WC_Matches"].astype("int64")

df_model["Lifetime_WC_Matches_Bin"] = df_model["Lifetime_WC_Matches_Bin"].fillna(0)
df_model["Lifetime_WC_Matches_Bin"] = df_model["Lifetime_WC_Matches_Bin"].astype("int64")

df_model["Lifetime_WC_Matches_Bin4"] = df_model["Lifetime_WC_Matches_Bin4"].fillna(0)
df_model["Lifetime_WC_Matches_Bin4"] = df_model["Lifetime_WC_Matches_Bin4"].astype("int64")

df_model["Lifetime_WC_Matches_Bin5"] = df_model["Lifetime_WC_Matches_Bin5"].fillna(0)
df_model["Lifetime_WC_Matches_Bin5"] = df_model["Lifetime_WC_Matches_Bin5"].astype("int64")

df_model["Lifetime_WC_Matches_Bin10"] = df_model["Lifetime_WC_Matches_Bin10"].fillna(0)
df_model["Lifetime_WC_Matches_Bin10"] = df_model["Lifetime_WC_Matches_Bin10"].astype("int64")

# df_model.describe()

# %%
# DROPPING ROWS FOR PLAYERS WHO HAVE NEVER APPEARED IN THE WORLD CUP
df_model = df_model.loc[df_model["Lifetime_WC_Matches_Bin"]==1]
# df_model.describe()

# %%
# CORRELATION OF FEATURES FOR 2021 PLAYERS WHO HAVE APPEARED IN AT LEAST ONE WORLD CUP MATCH
corrMatrix = df_model.corr()
sn.heatmap(corrMatrix, annot = True)
# plt.figure(figsize = (25,25))
plt.show()

# %%
lifetime_appearances = df_model["Lifetime_WC_Matches"]

# INVESTIGATION Y
lifetime_appearances.value_counts()
# lifetime_appearances.mean()
# lifetime_appearances.median()
# lifetime_appearances.mode()
# Out:
# 3     175
# 1     119
# 2     105
# 4      87
# 5      48
# 6      39
# 7      32
# 8      22
# 10     13
# 9      12
# 12     12
# 11     10
# 14      8
# 16      4
# 13      3
# 17      2
# 15      2
# 19      1
# Name: Lifetime_WC_Matches, dtype: int64

# %% [markdown]
# # Player Features Modeling

# %%
# # DEFINE X AND Y FOR THE MODEL
# # CHALLENGE IS COMPENSATING FOR THE UNBALANCED DATASET. 

# # ------- OPTION A ------- returns test score of 22.41% (MULTICLASS)
# # WHERE THE TARGET IS THE NUMBER OF LIFETIME WORLD CUP MATCHES PER 2021 PLAYER
# model_option_name = "Multiclass - All Lifetime WC Appearances"
# X = df_model.drop(["Lifetime_WC_Matches", "Lifetime_WC_Matches_Bin", 
#                    "Lifetime_WC_Matches_Bin4", "Lifetime_WC_Matches_Bin10", "Lifetime_WC_Matches_Bin5"], axis=1)
# y = df_model["Lifetime_WC_Matches"]

# ------- OPTION B ------- returns test score of 62.64%
# WHERE THE TARGET IS IF THE PLAYER HAS HAD MORE THAN 3 WC APPERANCES (295 OF 694, 42.5%)
model_option_name = "If players had 4 or more Lifetime WC Apperances"
X = df_model.drop(["Lifetime_WC_Matches", "Lifetime_WC_Matches_Bin", 
                   "Lifetime_WC_Matches_Bin4", "Lifetime_WC_Matches_Bin10", "Lifetime_WC_Matches_Bin5"], axis=1)
y = df_model["Lifetime_WC_Matches_Bin4"]

# # ------- OPTION B.2 ------- returns test score of 70.1%
# # WHERE THE TARGET IS IF THE PLAYER HAS HAD MORE THAN 4 WC APPERANCES (208 OF 694, 30.0%)
# model_option_name = "If players had 5 or more Lifetime WC Apperances"
# X = df_model.drop(["Lifetime_WC_Matches", "Lifetime_WC_Matches_Bin", 
#                    "Lifetime_WC_Matches_Bin4", "Lifetime_WC_Matches_Bin10", "Lifetime_WC_Matches_Bin5"], axis=1)
# y = df_model["Lifetime_WC_Matches_Bin5"]

# # ------- OPTION C ------- returns test score of 85.63%
# # WHERE THE TARGET IS IF THE PLAYER HAS HAD AT LEAST 9 WC APPERANCES (67 OF 694, 9.7%)
# model_option_name = "If players had 9 or more Lifetime WC Apperances"
# X = df_model.drop(["Lifetime_WC_Matches", "Lifetime_WC_Matches_Bin", 
#                    "Lifetime_WC_Matches_Bin4", "Lifetime_WC_Matches_Bin10", "Lifetime_WC_Matches_Bin5"], axis=1)
# y = df_model["Lifetime_WC_Matches_Bin10"]

# count
y.value_counts()
# Out:
# 0    399
# 1    295
# Name: Lifetime_WC_Matches_Bin4, dtype: int64

# %%
# SPLIT AND TRAIN MODEL
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=13)
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Target used: {model_option_name}")
print("-"*50)
print(f"Maximum X_train_scaled value: {X_train_scaled.max().round(4)}")
print(f"Minimum X_train_scaled value: {X_train_scaled.min().round(4)}")
print("-"*50)
print(f"Maximum X_test_scaled value: {X_test_scaled.max().round(4)}")
print(f"Minimum X_test_scaled value: {X_test_scaled.min().round(4)}")
# Out:
# Target used: If players had 4 or more Lifetime WC Apperances
# --------------------------------------------------
# Maximum X_train_scaled value: 4.5303
# Minimum X_train_scaled value: -4.6576
# --------------------------------------------------
# Maximum X_test_scaled value: 4.3231
# Minimum X_test_scaled value: -3.9085

# %%
# RANDOM FOREST CLASSIFIER MODEL
clf = RandomForestClassifier(random_state=37, n_estimators=1000).fit(X_train_scaled, y_train)

print(f"Target used: {model_option_name}")
print("-"*50)
print(f'Training Score: {clf.score(X_train_scaled, y_train).round(4)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test).round(4)}')
# Out:
# Training Score: 0.9981
# Testing Score: 0.6264

# %%
# IDENTIFYING FEATURE IMPORTANCE
features = clf.feature_importances_.round(4)
feature_names = list(X_train.columns.values)

# %%
# PLOTTING THE FEATURE IMPORTANCE ANALYSIS

# MAKING A DATAFRAME OF THE FEATURES ANALYSIS OUTPUT
features_list = pd.Series(features)
featuresnames_list = pd.Series(feature_names)
features_df = pd.concat([featuresnames_list, features_list], axis = 1)
features_df = features_df.sort_values(by=1, ascending = True)
# features_df.rename(columns = {"0: Feature Name", "1: Importance Value"})

plt.figure(figsize = (25,25))
plt.title(f"Feature Importance: {model_option_name}", fontsize=25)
plt.xlabel("Importance", fontsize=22)
plt.xticks(fontsize=25)

plt.barh(range(len(features_df[1])), features_df[1], color="maroon", edgecolor="darkred")
plt.yticks(range(len(features_df[1])), features_df[0], fontsize = 20)
plt.show()

# %%
# NUMBER OF TOP FEATURES TO INCLUDE
n = 5

# DATAFRAME FOR TOP FEATURES
top_features_df = features_df.sort_values(by=1, ascending = False).head(n)
# top_features_df

# CREATE LIST OF TOP N MOST IMPORTANT FEATURES
top_features_list = top_features_df[0].to_list()

# %%
print(f"Target used: {model_option_name}")
print("-"*50)
print(f"Average Importance of All Features: {features.mean().round(4)}")
print(f"Maximum Importance of All Features: {features.max().round(4)}")
print(f"Minimum Importance of All Features: {features.min().round(4)}")
print("-"*50)

print(f"The Top {len(features_df.sort_values(by=1, ascending = False).head(n))} \
Most Important Features Impacting a Player's World Cup Apperance:")
print(f"{top_features_list}")
# Out:
# Target used: If players had 4 or more Lifetime WC Apperances
# --------------------------------------------------
# Average Importance of All Features: 0.0244
# Maximum Importance of All Features: 0.0438
# Minimum Importance of All Features: 0.0041
# --------------------------------------------------
# The Top 5 Most Important Features Impacting a Player's World Cup Apperance:
# ['Composure', 'Overall', 'Potential', 'Volleys', 'Reactions']

# %%
# y_train.value_counts()
# y_test.value_counts()

# othe roptions: smote - synthetic data to up/down sample; precision recall metrics instead of test/train score

# %%
# # SHAP PLOT

# # X, y = shap.datasets.adult()
# model = xgboost.XGBClassifier().fit(X, y)
# explainer = shap.TreeExplainer(model, X)
# shap_values = explainer(X)
# feature_names = [
#     a + ": " + str(b) for a,b in zip(X.columns, np.abs(shap_values.values).mean(0).round(2))
# ]

# shap.summary_plot(shap_values, X, max_display=X.shape[1], 
#                   feature_names=feature_names)

# # expecting that y is label encoded
# # change y to 1 or 0 , that the player appeared in the WC; if y = 0 then 0 else y = 1
# # alternative: multiclass classification; 
# # or could do regression (lin or ranfor) to predict continuous number

# %%
# clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
# print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
# print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')

# %%
# feature_importances = clf.feature_importances_
# features = sorted(zip(X.columns, clf.feature_importances_), key = lambda x: x[1])
# cols = [f[0] for f in features]
# width = [f[1] for f in features]

# fig, ax = plt.subplots()

# fig.set_size_inches(10)
# plt.margins(y=0.001)

# ax.barh(y=cols, width=width)

# plt.show()

# %% [markdown]
# # create many features based on statistics per each country

# %%
#only keep countries that are in the 2022 World Cup
data_df = data_df[(data_df['Country'].isin(teams_2022))]
data_df
# Out:
#            ID               Name    Country  Overall  Potential  Height  \
# 0      158023       Lionel Messi  Argentina       93         93     170
# 2      182521         Toni Kroos    Germany       88         88     183
# 3      202652    Raheem Sterling    England       88         90     170
# 4      183277        Eden Hazard    Belgium       88         88     175
# 5      210257            Ederson     Brazil       88         91     188
# ...       ...                ...        ...      ...        ...     ...
# 19111  190871          Neymar Jr     Brazil       91         91     175
# 19112  192985    Kevin De Bruyne    Belgium       91         91     181
# 19114   20801  Cristiano Ronaldo   Portugal       92         92     187
# 19115  230237       Robson Denho     Brazil       74         74     181
# 19116  230230    Eltildo Correia     Brazil       74         74     188
#
#        Weight PreferredFoot      BirthDate  Age PreferredPositions  \
# 0          72             L  June 24, 1987   33           RW/ST/CF
# 2          76             R   Jan. 4, 1990   30                 CM
# 3          69             R   Dec. 8, 1994   25              LW/RW
# 4          74             R   Jan. 7, 1991   29                 LW
# 5          86             L  Aug. 17, 1993   27                 GK
# ...       ...           ...            ...  ...                ...
# 19111      68             R   Feb. 5, 1992   28             LW/CAM
# 19112      70             R  June 28, 1991   29             CM/CAM
# 19114      83             R   Feb. 5, 1985   35              ST/LW
# 19115      78             R  Feb. 29, 1992   28             CDM/CM
# 19116      78             R  Feb. 29, 1992   28           CB/RB/LB
#
#       PlayerWorkRate  WeakFoot  SkillMoves        Value      Wage     Nation  \
# 0         Medium/Low         4           4  103500000.0  560000.0  Argentina
# 2      Medium/Medium         5           3   87500000.0  310000.0    Germany
# 3        High/Medium         4           4  114500000.0  270000.0    England
# 4        High/Medium         4           4   89500000.0  350000.0    Belgium
# 5      Medium/Medium         3           1   92000000.0  195000.0        NaN
# ...              ...       ...         ...          ...       ...        ...
# 19111    High/Medium         5           5  132000000.0  270000.0        NaN
# 19112      High/High         5           4  127500000.0  370000.0    Belgium
# 19114       High/Low         4           5   63000000.0  215000.0   Portugal
# 19115      High/High         3           2    3700000.0   12000.0        NaN
# 19116  Medium/Medium         3           2    3600000.0   27500.0        NaN
#
#       Nation_Position  Nation_KitNumber                       Club  \
# 0                  RW              10.0               FC Barcelona
# 2                 LCM               8.0                Real Madrid
# 3                  LW               7.0            Manchester City
# 4                  LF              10.0                Real Madrid
# 5                 NaN               NaN            Manchester City
# ...               ...               ...                        ...
# 19111             NaN               NaN        Paris Saint-Germain
# 19112             RCM               7.0            Manchester City
# 19114              LS               7.0                   Juventus
# 19115             NaN               NaN  Atlético Clube Goianiense
# 19116             NaN               NaN           Atlético Mineiro
#
#       Club_Position  Club_KitNumber Club_JoinedClub Club_ContractLength  \
# 0               CAM              10    July 1, 2004                2021
# 2               LCM               8   July 17, 2014                2023
# 3                LW               7   July 14, 2015                2023
# 4               Sub               7    July 1, 2019                2024
# 5                GK              31    July 1, 2017                2024
# ...             ...             ...             ...                 ...
# 19111            LW              10    Aug. 3, 2017                2022
# 19112           RCM              17   Aug. 30, 2015                2023
# 19114            LS               7   July 10, 2018                2022
# 19115           CDM              44    Jan. 1, 2019                2023
# 19116           RCB               4    Jan. 1, 2019                2023
#
#        BallControl  Dribbling  Marking  SlideTackle  StandTackle  Aggression  \
# 0               96         96       32           24           35          44
# 2               89         80       72           60           73          60
# 3               88         90       47           47           53          59
# 4               91         93       34           22           27          54
# 5               40         23       29            8           15          38
# ...            ...        ...      ...          ...          ...         ...
# 19111           95         95       35           29           30          51
# 19112           92         88       68           53           65          76
# 19114           92         88       28           24           32          63
# 19115           66         61       77           71           76          78
# 19116           55         45       79           77           75          80
#
#        Reactions  AttPosition  Interceptions  Vision  Composure  Crossing  \
# 0             94           93             40      95         96        85
# 2             89           76             79      90         88        88
# 3             90           91             30      82         79        78
# 4             86           85             41      86         90        77
# 5             87           20             27      70         70        20
# ...          ...          ...            ...     ...        ...       ...
# 19111         91           87             36      90         93        85
# 19112         91           88             66      94         91        94
# 19114         95           95             29      82         95        84
# 19115         68           71             74      77         66        65
# 19116         77           42             72      44         75        61
#
#        ShortPass  LongPass  Acceleration  Stamina  Strength  Balance  \
# 0             91        91            91       72        69       95
# 2             93        93            57       75        72       71
# 3             84        69            96       79        71       94
# 4             85        81            91       82        63       93
# 5             57        59            64       41        78       48
# ...          ...       ...           ...      ...       ...      ...
# 19111         87        81            94       81        50       83
# 19112         94        93            77       89        74       76
# 19114         82        77            87       84        78       71
# 19115         74        68            66       83        75       64
# 19116         67        75            50       69        75       51
#
#        SprintSpeed  Agility  Jumping  Heading  ShotPower  Finishing  \
# 0               80       91       68       70         86         95
# 2               52       63       32       58         89         76
# 3               88       94       57       46         78         84
# 4               86       92       56       61         82         82
# 5               63       60       66       14         70         14
# ...            ...      ...      ...      ...        ...        ...
# 19111           89       96       62       62         80         87
# 19112           76       78       63       55         91         82
# 19114           91       87       95       90         94         95
# 19115           62       61       66       53         82         54
# 19116           61       38       86       73         71         41
#
#        LongShots  Curve  FKAcc  Penalties  Volleys  GKPositioning  GKDiving  \
# 0             94     93     94         75       88             14         6
# 2             86     86     84         73       82              7        10
# 3             79     77     63         69       67             15        15
# 4             78     83     79         87       83              8        11
# 5             18     15     20         17       18             86        86
# ...          ...    ...    ...        ...      ...            ...       ...
# 19111         84     88     89         92       87             15         9
# 19112         91     85     83         84       82             10        15
# 19114         93     81     76         84       86             14         7
# 19115         42     79     76         73       45             13        13
# 19116         45     54     48         77       52              7         7
#
#        GKHandling  GKKicking  GKReflexes  \
# 0              11         15           8
# 2              11         13          10
# 3              12         12           9
# 4              12          6           8
# 5              82         93          88
# ...           ...        ...         ...
# 19111           9         15          11
# 19112          13          5          13
# 19114          11         15          11
# 19115          13         14           9
# 19116          15         13          11
#
#                                                   Traits  \
# 0      Finesse Shot/Long Shot Taker (CPU AI Only)/Spe...
# 2      Long Passer (CPU AI Only)/Long Shot Taker (CPU...
# 3                     Flair/Speed Dribbler (CPU AI Only)
# 4      Injury Prone/Finesse Shot/Flair/Playmaker (CPU...
# 5      Long Passer (CPU AI Only)/Rushes Out Of Goal/C...
# ...                                                  ...
# 19111  Injury Prone/Flair/Speed Dribbler (CPU AI Only...
# 19112  Injury Prone/Leadership/Early Crosser/Long Pas...
# 19114  Power Free-Kick/Flair/Long Shot Taker (CPU AI ...
# 19115                                    Power Free-Kick
# 19116                                        Team Player
#
#                                             Specialities
# 0      Dribbler/Distance Shooter/FK Specialist/Acroba...
# 2      Playmaker/Distance Shooter/Crosser/Complete Mi...
# 3                             Speedster/Dribbler/Acrobat
# 4                                       Dribbler/Acrobat
# 5                                                    NaN
# ...                                                  ...
# 19111  Speedster/Dribbler/Playmaker/FK Specialist/Acr...
# 19112  Dribbler/Playmaker/Engine/Distance Shooter/Cro...
# 19114  Aerial Threat/Dribbler/Distance Shooter/Acroba...
# 19115                                                NaN
# 19116                                                NaN
#
# [12548 rows x 60 columns]

# %%
data_df = data_df.drop(columns = 'ID')

# %%
data_df.columns
#which attribute features do we want out of the following column names?
# Out:
# Index(['Name', 'Country', 'Overall', 'Potential', 'Height', 'Weight',
#        'PreferredFoot', 'BirthDate', 'Age', 'PreferredPositions',
#        'PlayerWorkRate', 'WeakFoot', 'SkillMoves', 'Value', 'Wage', 'Nation',
#        'Nation_Position', 'Nation_KitNumber', 'Club', 'Club_Position',
#        'Club_KitNumber', 'Club_JoinedClub', 'Club_ContractLength',
#        'BallControl', 'Dribbling', 'Marking', 'SlideTackle', 'StandTackle',
#        'Aggression', 'Reactions', 'AttPosition', 'Interceptions', 'Vision',
#        'Composure', 'Crossing', 'ShortPass', 'LongPass', 'Acceleration',
#        'Stamina', 'Strength', 'Balance', 'SprintSpeed', 'Agility', 'Jumping',
#        'Heading', 'ShotPower', 'Finishing', 'LongShots', 'Curve', 'FKAcc',
#        'Penalties', 'Volleys', 'GKPositioning', 'GKDiving', 'GKHandling',
#        'GKKicking', 'G
# 5   38.727273      18.064935  18.857143   17.064935  16.740260   18.025974
# 6   46.068966      12.827586  13.206897   13.310345  12.068966   14.241379
# 7   45.392593      17.266667  17.407407   16.703704  16.437037   17.133333
# 8   42.354098      15.718033  15.770492   15.622951  15.816393   16.124590
# 9   40.457490      15.821862  15.692308   15.740891  15.615385   15.931174
# 10  40.319372      15.452007  15.757999   15.696917  15.456079   15.900524
# 11  43.576541      15.719682  15.820080   15.544732  15.483101   16.099404
# 12  41.247699      17.540586  18.082845   17.765690  17.215063   18.061088
# 13  48.598361      11.393443  11.909836   11.508197  11.573770   11.393443
# 14  48.421053      20.526316  20.315789   19.842105  19.736842   21.105263
# 15  41.752577      15.964948  16.241237   16.167010  15.828866   16.317526
# 16  38.391813      17.149123  17.380117   16.988304  16.769006   17.453216
# 17  42.357923      17.428962  17.546448   17.677596  17.355191   17.680328
# 18  53.048193      12.879518  12.530120   13.409639  12.132530   12.349398
# 19  43.963043      17.700000  18.095652   17.689130  17.702174   18.145652
# 20  39.429775      17.233146  17.786517   17.404494  16.797753   17.755618
# 21  48.005540      15.806094  15.889197   16.005540  15.387812   16.229917
# 22  36.411392      16.300633  16.354430   16.123418  15.955696   16.550633
# 23  45.281481      14.237037  14.688889   14.088889  14.362963   14.992593
# 24  45.804511      16.045113  15.518797   15.360902  15.255639   16.015038
# 25  44.752530      16.856486  17.188592   16.993560  16.811408   17.266789
# 26  41.842105      17.258373  17.354067   17.133971  16.626794   17.354067
# 27  47.310345      11.241379  12.379310   11.103448  12.206897   13.241379
# 28  38.833760      19.560102  20.120205   19.447570  20.053708   20.335038
# 29  44.104046      15.268786  14.913295   14.950867  15.095376   15.170520
# 30  40.609756      15.926829  16.065041   15.788618  15.853659   15.739837

# %%
# median stats of each player to get an overall 'score' for each team
median_for_teams = data_df.groupby(["Country"]).median()
median_for_teams = median_for_teams.reset_index()
len(median_for_teams)
# Out:
# 31

# %%
# median stats of each player to get an overall 'score' for each team
max_for_teams = data_df.groupby(["Country"]).max()
max_for_teams = max_for_teams.reset_index()
len(max_for_teams)
# Out:
# C:\Users\madis\AppData\Local\Temp/ipykernel_29144/932889033.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   max_for_teams = data_df.groupby(["Country"]).max()
# 31

# %%
# min stats of each player to get an overall 'score' for each team
min_for_teams = data_df.groupby(["Country"]).min()
min_for_teams = min_for_teams.reset_index()
len(min_for_teams)
# Out:
# C:\Users\madis\AppData\Local\Temp/ipykernel_29144/3565807590.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   min_for_teams = data_df.groupby(["Country"]).min()
# 31

# %%
std_for_teams = data_df.groupby(["Country"]).std()
std_for_teams = std_for_teams.reset_index()
len(std_for_teams)
# Out:
# 31

# %% [markdown]
# #Features showing only certain positions: Goalie, for example

# %%
#only goalies
goalies = data_df.loc[data_df['Nation_Position'] == 'GK']
len(goalies)
# Out:
# 20

# %%
#we only have 20 known goalies available
max_for_goalies = goalies.groupby("Country").max()
max_for_goalies = max_for_goalies.reset_index()
max_for_goalies
# Out:
#           Country                      Name  Overall  Potential  Height  \
# 0       Argentina             Franco Armani       80         80     189
# 1       Australia               Mathew Ryan       79         81     184
# 19  Medium/Medium         3           1   1800000.0   34000.0          Wales
#
#    Nation_Position  Nation_KitNumber                      Club Club_Position  \
# 0               GK               1.0               River Plate            GK
# 1               GK               1.0    Brighton & Hove Albion            GK
# 2               GK               1.0               Real Madrid            GK
# 3               GK               1.0                    Grêmio            GK
# 4               GK              23.0                      Ajax            GK
# 5               GK              18.0               Free Agents           Res
# 6               GK               1.0            Leicester City            GK
# 7               GK              23.0               Free Agents           Res
# 8               GK               1.0                   Everton            GK
# 9               GK               1.0         Tottenham Hotspur            GK
# 10              GK               1.0         FC Bayern München            GK
# 11              GK              13.0              Club América            GK
# 12              GK               1.0               Valencia CF           Sub
# 13              GK              22.0           West Ham United            GK
# 14              GK               1.0   Wolverhampton Wanderers            GK
# 15              GK               1.0         Manchester United            GK
# 16              GK               1.0  Borussia Mönchengladbach            GK
# 17              GK               1.0           Manchester City           Sub
# 18              GK               1.0               Free Agents           Res
# 19              GK               1.0            Crystal Palace           Res
#
#     Club_KitNumber Club_JoinedClub Club_ContractLength  BallControl  \
# 0                1   Jan. 12, 2018                2022           35
# 1                1    July 1, 2017                2022           24
# 2                1    Aug. 9, 2018                2024           23
# 3               16    Jan. 1, 2019                2023           21
# 4               24   Jan. 14, 2015                2022           38
# 5               99    Feb. 6, 2020                2024           23
# 6                1    June 1, 2011                2023           40
# 7               99    Jan. 1, 2014                2024           25
# 8                1   June 15, 2017                2024           40
# 9                1   Aug. 31, 2012                2022           34
# 10               1    July 1, 2011                2023           46
# 11              13    Aug. 6, 2019                2024           18
# 12              13    July 1, 2019                2023           32
# 13               1   June 20, 2018                2021           22
# 14              11   June 18, 2018                2022           25
# 15               1    July 1, 2011                2023           38
# 16               1    July 1, 2014                2023           25
# 17              13    July 1, 2019                2022           31
# 18              99   Aug. 10, 2018                2023           21
# 19              13   Jan. 31, 2014                2021           23
#
#     Dribbling  Marking  SlideTackle  StandTackle  Aggression  Reactions  \
# 0          19       15           19           13          45         77
# 1          13       10           17           20          36         72
# 2          13       20           16           18          23         84
# 3           9       20           13           17          34         82
# 4          26       12           14           18          32         83
# 5          28       21           21           23          44         73
# 6          12       14           13           14          35         81
# 7          12       18            9            7          40         63
# 8          14       21           12           20          45         77
# 9          10       29           18           10          31         85
# 10         30       17           11           10          29         87
# 11         10       21           12           10          19         74
# 12         12       18           11           12          25         79
# 13         14       14           13           12          43         75
# 14         20       14           11           13          37         79
# 15         18       25           13           21          38         83
# 16         15        9           12           19          38         82
# 17         15       13           12           12          31         72
# 18          9       12           13           17          34         78
# 19          8       13           13           18          21         68
#
#     AttPosition  Interceptions  Vision  Composure  Crossing  ShortPass  \
# 0            17             21      55         53        18         37
# 1            10             23      68         64        23         40
# 2            13             15      44         66        14         33
# 3            27             23      71         67        10         18
# 4            11             15      64         64        15         43
# 5            14             24      57         60        15         38
# 6            13             20      59         67        18         44
# 7            16             26      15         21        13         18
# 8            18             24      69         64        17         55
# 9            10             27      30         65        13         50
# 10           12             30      70         70        15         60
# 11           16             23      48         57        15         31
# 12           11             25      60         61        17         50
# 13           15             16      52         63        14         20
# 14           13             23      64         66        12         34
# 15           12             30      61         65        17         50
# 16           15             21      64         57        13         40
# 17            9             19      57         56        14         51
# 18           27             23      71         67        10         18
# 19           14             22      58         55        11         29
#
#     LongPass  Acceleration  Stamina  Strength  Balance  SprintSpeed  Agility  \
# 0         29            41       35        81       39           45       37
# 1         45            53       34        65       50           52       53
# 2         35            42       38        70       45           52       61
# 3         16            41       29        79       41           42       34
# 4         53            64       39        79       53           62       68
# 5         48            47       43        79       46           40       40
# 6         46            50       34        64       47           55       61
# 7         27            34       38        71       41           26       43
# 8         56            53       45        70       55           44       55
# 9         50            65       41        43       54           62       55
# 10        68            54       43        80       35           60       51
# 11        32            47       34        56       42           50       65
# 12        35            56       40        67       50           50       48
# 13        32            50       25        65       44           47       53
# 14        32            53       45        77       54           57       61
# 15        47            57       43        60       43           58       63
# 16        31            48       45        68       58           54       55
# 17        52            54       39        69       49           52       58
# 18        16            41       29        79       41           42       34
# 19        41            40       29        68       51           41       48
#
#     Jumping  Heading  ShotPower  Finishing  LongShots  Curve  FKAcc  \
# 0        67       19         50         11         17     15     16
# 1        78       14         62         11         18     23     12
# 2        68       13         56         14         17     19     20
# 3        67       11         58          8          7      9     18
# 4        80       20         65         12         17     30     17
# 5        64       24         54         12         12     16     16
# 6        60       16         62         12         14     13     15
# 7        55       27         61          6         13     23     12
# 8        77       15         65         19         13     18     16
# 9        74       10         51         10         14     11     10
# 10       77       25         68         13         16     14     11
# 11       75       19         56         12         11     14     17
# 12       71       12         59         10         15     10     10
# 13       69       11         53         13         20     18     12
# 14       79       11         58         12         11     10     16
# 15       67       21         59         13         12     21     19
# 16       73       10         64         13         12     12     13
# 17       71       13         55          9         12     13     11
# 18       67       11         58          8          7      9     18
# 19       41       14         59         12         10     12     11
#
#     Penalties  Volleys  GKPositioning  GKDiving  GKHandling  GKKicking  \
# 0          20       18             81        78          76         67
# 1          25       15             78        81          75         82
# 2          27       12             85        84          89         74
# 3          14        8             83        79          84         77
# 4          27       13             83        84          80         87
# 5          23       19             74        76          74         72
# 6          26       15             80        83          77         83
# 7          25       13             75        71          79         81
# 8          45       20             76        81          75         87
# 9          40       11             84        89          82         68
# 10         47       11             88        88          88         91
# 11         16       16             79        77          69         75
# 12         21       19             80        80          81         78
# 13         22       17             81        80          82         70
# 14         32       16             82        84          80         77
# 15         29       13             81        88          81         78
# 16         24        8             86        80          84         85
# 17         37        8             71        77          72         73
# 18         14        8             80        78          81         77
# 19         17       10             75        76          74         79
#
#     GKReflexes                                             Traits  \
# 0           86                   Leadership/Cautious With Crosses
# 1           82                   GK Long Throw/Rushes Out Of Goal
# 2           88                    GK Long Throw/Comes For Crosses
# 3           78                                        Team Player
# 4           86  Leadership/Rushes Out Of Goal/Comes For Crosse...
# 5           72                                  Comes For Crosses
# 6           89                                         Leadership
# 7           69                                                NaN
# 8           85  Long Passer (CPU AI Only)/Solid Player/Rushes ...
# 9           90    Leadership/Rushes Out Of Goal/Comes For Crosses
# 10          89  Leadership/GK Long Throw/Rushes Out Of Goal/Co...
# 11          83                GK Long Throw/Cautious With Crosses
# 12          79                     Injury Prone/Comes For Crosses
# 13          82                    GK Long Throw/Comes For Crosses
# 14          83                 Solid Player/Cautious With Crosses
# 15          89  Solid Player/Cautious With Crosses/Saves with ...
# 16          84                                  Comes For Crosses
# 17          83                                    Saves with Feet
# 18          77                                        Team Player
# 19          71               Rushes Out Of Goal/Comes For Crosses
#
#     Specialities
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           Na
#        'CB/ST', 'CAM/LW/CF', 'CM/RM/RB', 'LWB/LM/ST', 'CDM/CB/LM',
#        'CAM/LM/RW', 'LW/LB', 'LM/LB/CB', 'CDM/LM', 'RWB/RM/LM',
#        'CM/CAM/RB', 'LB/LWB/LW', 'CAM/LWB/RWB', 'CF/LM/LW', 'RM/CF/LM'],
#       dtype=object)

# %%
#only goalies
goalies2 = data_df.loc[data_df['PreferredPositions'] == 'GK']
len(goalies2)
# Out:
# 1404

# %%
max_for_goalies2 = goalies2.groupby("Country").max()
max_for_goalies2 = max_for_goalies2.reset_index()
max_for_goalies2
# Out:
# C:\Users\madis\AppData\Local\Temp/ipykernel_29144/2078748855.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   max_for_goalies2 = goalies2.groupby("Country").max()
#            Country                  Name  Overall  Potential  Height  Weight  \
# 0        Argentina       Willy Caballero       82         84     196      94
# 1        Australia     Vedran Janjetović       79         81     198      95
# 2          Belgium       Yannick Thoelen       89         90     199      96
# 3           Brazil       Wiliam Santinho       90         91     196      93
# 4         Cameroon        Simon Omossola       84         88     190      93
# 5           Canada          Thomas Hasal       75         75     196      88
# 6       Costa Rica          Keylor Navas       88         88     185      80
# 7          Croatia           Simon Sluga       81         86     201      99
# 8          Denmark      Thomas Mikkelsen       84         84     199      99
# 9          Ecuador       Álvaro Preciado       74         75     199     104
# 10         England          Zach Jeacock       82         87     203      97
# 11          France         Yohann Thuram       87         87     198      98
# 12         Germany        Yannik Bangsow       90         93     199     103
# 13           Ghana         Richard Ofori       71         76     190      83
# 14            Iran          Sosha Makani       73         75     194      81
# 15           Japan              Yuya Oki       72         78     198      97
# 16  Korea Republic       Yun Pyeong Gook       75         77     197      93
# 17          Mexico      Sebastián Jurado       79         80     196      92
# 18         Morocco        Yassine Bounou       76         77     192      89
# 19     Netherlands  Youri Schoonderwaldt       81         86     202     103
# 20          Poland      Łukasz Skorupski       87         87     199      91
# 21        Portugal              Tiago Sá       84         84     196      98
# 22    Saudi Arabia       Zaid Al Bawardi       71         72     191      90
# 23         Senegal         Édouard Mendy       80         82     202      92
# 24          Serbia        Živko Živković       81         83     202      94
# 25           Spain         Óscar Whalley       86         86     197      96
# 26     Switzerland    Živko Kostadinović       85         85     196      93
# 27         Tunisia         Elias Damergy       58         71     187      76
# 28   United States          Zack Steffen       76         82     201     107
# 29         Uruguay         Álvaro García       82         82     193      88
# 30           Wales       Wayne Hennessey       75         75     198      90
#
#    PreferredFoot       BirthDate  Age PreferredPositions PlayerWorkRate  \
# 0              R  Sept. 28, 1981   42                 GK  Medium/Medium
# 1              R  Sept. 28, 1999   39                 GK  Medium/Medium
# 2              R   Sept. 7, 1993   41                 GK  Medium/Medium
# 3              R   Sept. 3, 1993   40                 GK  Medium/Medium
# 4              R     May 5, 1998   24                 GK  Medium/Medium
# 5              R   Oct. 23, 1987   41                 GK  Medium/Medium
# 6              R   Dec. 15, 1986   33                 GK  Medium/Medium
# 7              R    May 30, 1991   33                 GK  Medium/Medium
# 8              R  Sept. 25, 1995   39                 GK  Medium/Medium
# 9              R   Sept. 8, 2000   36                 GK  Medium/Medium
# 10             R   Sept. 9, 1994   39                 GK  Medium/Medium
# 11             R   Sept. 8, 2000   39                 GK  Medium/Medium
# 12             R   Sept. 9, 1988   41                 GK  Medium/Medium
# 13             R   Nov. 29, 1996   27                 GK  Medium/Medium
# 14             R  Sept. 21, 1992   34                 GK  Medium/Medium
# 15             R   Sept. 8, 1994   41                 GK  Medium/Medium
# 16             R  Sept. 30, 1990   37                 GK  Medium/Medium
# 17             R   Sept. 5, 1985   39                 GK  Medium/Medium
# 18             R   Nov. 29, 1991   31                 GK  Medium/Medium
# 19             R   Sept. 7, 1996   38                 GK  Medium/Medium
# 20             R   Sept. 5, 1989   40                 GK  Medium/Medium
# 21             R  Sept. 27, 1996   33                 GK  Medium/Medium
# 22             R  Sept. 24, 1985   39                 GK  Medium/Medium
# 23             R   Sept. 5, 1993   28                 GK  Medium/Medium
# 24             R   Oct. 31, 1995   32                 GK  Medium/Medium
# 25             R   Sept. 5, 2003   39                 GK  Medium/Medium
# 26             R  Sept. 18, 1987   36                 GK  Medium/Medium
# 27             R   Oct. 17, 2002   18                 GK  Medium/Medium
# 28             R   Sept. 9, 1984   36                 GK  Medium/Medium
# 29             R   Sept. 9, 1994   37                 GK  Medium/Medium
# 30             R  Sept. 20, 1997   36                 GK  Medium/Medium
#
#     WeakFoot  SkillMoves        Value      Wage  Nation_KitNumber  \
# 0          4           1   25500000.0   85000.0              23.0
# 1          4           1   15000000.0   50000.0              18.0
# 2          4           1   82000000.0  250000.0              13.0
# 3          5           1  102000000.0  195000.0              23.0
# 4          3           1   48000000.0   18000.0              23.0
# 5          3           1    2000000.0    4200.0              18.0
# 6          3           1   29500000.0  130000.0               NaN
# 7          3           1   30000000.0   33000.0               NaN
# 8          4           1   13500000.0   90000.0              22.0
# 9          4           1    2000000.0   10500.0              23.0
# 10         5           1   36000000.0   70000.0              22.0
# 11         4           1   34500000.0  125000.0              23.0
# 12         5           1  110000000.0  260000.0              22.0
# 13         3           1    2300000.0    8100.0               NaN
# 14         3           1    2800000.0   11000.0               NaN
# 15         4           1    2300000.0    7100.0               NaN
# 16         4           1    4800000.0    7400.0               NaN
# 17         4           1    5000000.0   34000.0              13.0
# 18         4           1    6000000.0   19500.0               NaN
# 19         5           1   20500000.0   33000.0              23.0
# 20         4           1   53000000.0  105000.0              22.0
# 21         4           1   28000000.0   90000.0              22.0
# 22         4           1    1500000.0   18000.0               NaN
# 23         3           1   18000000.0   75000.0               NaN
# 24         5           1   20500000.0   29500.0               NaN
# 25         5           1   46500000.0  150000.0              23.0
# 26         4           1   32500000.0   65000.0              21.0
# 27         3           1     400000.0    1500.0               NaN
# 28         4           1    9500000.0   65000.0              22.0
# 29         4           1    5000000.0   65000.0              23.0
# 30         3           1    3200000.0   43000.0              21.0
#
#                         Club Club_Position  Club_KitNumber  \
# 0           Yeni Malatyaspor           Sub              41
# 1          Western United FC           Sub              46
# 2                  Willem II           Sub              99
# 3              Vasco da Gama           Sub              99
# 4                 Stoke City           Sub              99
# 5     Vancouver Whitecaps FC           Sub              99
# 6        Paris Saint-Germain            GK               1
# 7                  Sampdoria           Sub              71
# 28           20          45         74           20             30      61
# 29           23          39         78           27             28      71
# 30           20          35         70           19             25      58
#
#     Composure  Crossing  ShortPass  LongPass  Acceleration  Stamina  Strength  \
# 0          69        25         60        54            65       45        82
# 1          64        23         40        45            53       40        74
# 2          66        20         48        46            60       44        78
# 3          71        33         57        59            64       62        85
# 4          64        15         43        53            64       43        79
# 5          60        19         41        48            54       43        79
# 6          67        11         30        37            54       39        75
# 7          64        20         46        56            57       38        75
# 8          67        20         57        55            51       44        79
# 9          66        21         37        57            63       50        85
# 10         67        31         55        56            64       45        84
# 11         66        21         54        50            65       44        83
# 12         70        34         61        68            65       67        83
# 13         56        20         45        39            45       32        71
# 14         40        18         29        25            43       40        81
# 15         68        25         42        48            55       45        80
# 16         67        23         45        46            63       45        81
# 17         70        25         59        65            64       45        80
# 18         57        21         39        44            56       43        77
# 19         64        20         53        52            60       45        77
# 20         67        23         51        43            59       45        81
# 21         68        33         45        45            63       45        85
# 22         60        23         38        50            49       42        76
# 23         58        15         34        47            59       35        77
# 24         65        30         41        40            44       45        79
# 25         65        35         60        52            65       54        80
# 26         62        24         45        35            56       45        78
# 27         37        10         17        18            38       28        66
# 28         62        25         52        62            59       45        85
# 29         67        22         44        47            60       45        81
# 30         56        18         31        42            59       44        73
#
#     Balance  SprintSpeed  Agility  Jumping  Heading  ShotPower  Finishing  \
# 0        68           65       70       75       26         62         20
# 1        58           55       66       78       19         62         19
# 2        64           58       66       75       22         60         17
# 3        68           63       74       83       30         70         25
# 4        53           62       68       80       20         65         18
# 5        63           49       59       72       24         54         20
# 6        61           53       60       74       11         56         15
# 7        53           54       65       61       15         56         15
# 8        62           55       61       68       28         62         20
# 9        62           56       66       83       29         61         19
# 10       68           65       64       80       28         65         20
# 11       65           63       70       75       22         62         19
# 12       62           65       67       83       47         68         19
# 13       64           45       50       84       20         58         28
# 14       65           46       53       58       19         53         19
# 15       68           44       68       75       27         56         17
# 16       58           57       69       68       24         58         20
# 17       68           64       70       84       22         61         20
# 18       44           55       43       65       23         56         19
# 19       65           56       64       80       21         64         20
# 20       58           61       59       71       39         55         20
# 21       68           64       69       82       25         58         20
# 22       67           50       50       74       29         56         20
# 23       54           49       60       81       20         56         16
# 24       54           47       55       65       20         59         20
# 25       67           65       72       85       28         64         20
# 26       58           54       58       75       24         64         27
# 27       33           32       46       54       12         39          5
# 28       60           56       58       78       29         55         20
# 29       69           62       68       84       19         58         18
# 30       60           55       54       76       19         59         16
#
#     LongShots  Curve  FKAcc  Penalties  Volleys  GKPositioning  GKDiving  \
# 0          20     33     30         70       20             82        82
# 1          18     27     21         41       20             78        81
# 2          20     23     22         41       19             85        84
# 3          22     31     23         34       29             91        86
# 4          17     30     20         27       17             83        84
# 5          16     16     16         26       20             74        76
# 6          13     11     15         25       11             83        90
# 7          19     20     20         22       18             79        81
# 8          19     26     20         42       22             80        83
# 9          20     23     23         35       20             75        72
# 10         20     60     53         53       20             83        81
# 11         20     25     22         40       20             84        89
# 12         20     34     23         47       20             88        88
# 13         30     36     25         34       31             74        72
# 14         14     16     18         28       12             72        78
# 15         19     35     28         33       19             73        72
# 16         20     35     34         30       18             74        75
# 17         20     62     65         44       19             79        77
# 18         19     25     19         25       13             75        75
# 19         20     21     21         42       20             80        82
# 20         20     22     35         31       19             87        86
# 21         20     31     36         49       20             82        85
# 22         20     21     22         40       20             72        75
# 23         19     31     16         23       15             79        81
# 24         45     55     59         28       20             81        78
# 25         20     34     28         44       20             83        88
# 26         18     21     20         32       26             86        85
# 27          5     10     10         14        6             54        59
# 28         20     29     21         37       20             79        78
# 29         20     69     74         25       19             82        84
# 30         20     18     19         30       18             75        76
#
#     GKHandling  GKKicking  GKReflexes  Specialities
# 0           80         83          86           NaN
# 1           75         82          82           NaN
# 2           89         80          88           NaN
# 3           88         93          89           NaN
# 4           80         87          86           NaN
# 5           74         72          75           NaN
# 6           83         75          90           NaN
# 7           78         74          83           NaN
# 8           77         83          89           NaN
# 9           79         81          73           NaN
# 10          81         87          85           NaN
# 11          82         82          90           NaN
# 12          88         91          90           NaN
# 13          68         77          70           NaN
# 14          70         70          74           NaN
# 15          72         75          74           NaN
# 16          71         77          81           NaN
# 17          77         81          83           NaN
# 18          76         74          76           NaN
# 19          81         85          79           NaN
# 20          82         73          88           NaN
# 21          80         77          86           NaN
# 22          70         75          76           NaN
# 23          78         75          80           NaN
# 24          80         79          82           NaN
# 25          82         85          89           NaN
# 26          84         85          88           NaN
# 27          54         52          60           NaN
# 28          72         73          83           NaN
# 29          81         77          83           NaN
# 30          74         79          75           NaN

# %% [markdown]
# # Dataset does not identify the position each player will play in the world cup yet. However, we can look at preferred position to get a clue.

# %%
data_df['Nation_Position'].value_counts()
# data_df['Nation_Position'].count()
# Out:
# Sub    240
# GK      20
# LCB     20
# RCB     20
# LB      16
# LCM     16
# RB      16
# RCM     16
# ST      16
# RW      10
# LW      10
# CDM      9
# CAM      8
# LM       7
# RM       7
# CB       4
# LS       4
# RDM      4
# RS       4
# LDM      4
# LWB      2
# RWB      2
# RF       1
# LAM      1
# LF       1
# CM       1
# RAM      1
# Name: Nation_Position, dtype: int64

# %% [markdown]
# # SQL Database Connection

# %%
# Connect to local database

# protocol = 'postgresql'
# username = 'postgres'
# password = 'admin'
# host = 'localhost'
# port = 5432
# database_name = 'players_db'
# rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
# engine = create_engine(rds_connection_string)
# rds_connection_string
# Out:
# 'postgresql://postgres:admin@localhost:5432/players_db'

# %%
# Checking Tables Names in PgAdmin

# engine.table_names()
# Out:
# C:\Users\madis\AppData\Local\Temp/ipykernel_29144/3802555757.py:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# C:\ProgramData\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "players_db" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29144/3802555757.py in <module>
#       1 # Checking Tables Names in PgAdmin
#       2
# ----> 3 engine.table_names()
#
# <string> in table_names(self, schema, connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    3180         :param connection: Optional, use a specified connection.
#    3181         """
# -> 3182         with self._optional_conn_ctx_manager(connection) as conn:
#    3183             insp = inspection.inspect(conn)
#    3184             return insp.get_table_names(schema)
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2932     def _optional_conn_ctx_manager(self, connection=None):
#    2933         if connection is None:
# -> 2934             with self.connect() as conn:
#    2935                 yield conn
#    2936         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# C:\ProgramData\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "players_db" does not exist
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# player_info_df.to_sql(name='player_info', con=engine, if_exists='replace', index=False)

# %%
# matches_df.to_sql(name='matches', con=engine, if_exists='replace', index=False)

# %%
# averages_for_teams.to_sql(name='team_averages', con=engine, if_exists='replace', index=False)
